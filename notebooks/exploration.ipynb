# %% [markdown]
# # Exploration\n\nThis notebook is a lightweight placeholder for ad hoc EDA around price tails, generation drivers, and dispatch checks.

# %%
import pandas as pd\nfrom src.data.prices import fetch_day_ahead_prices\nfrom src.data.generation import fetch_generation_data\n\nprices = fetch_day_ahead_prices(start='2024-01-01', end='2024-12-31')\ngeneration = fetch_generation_data(start='2024-01-01', end='2024-12-31')\nprices.head(), generation.head()
